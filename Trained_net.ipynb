# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from IPython.display import Image, display

print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %% [markdown]
# # Inspect Data

# %%
train_csv = pd.read_csv('kaggle/train.csv')
print(train_csv.describe())
print(train_csv.head())
# Out:
#          has_cactus
# count  17500.000000
# mean       0.750629
# std        0.432662
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
#                                      id  has_cactus
# 0  0004be2cfeaba1c0361d39e2b000257b.jpg           1
# 1  000c8a36845c0208e833c79c1bffedd1.jpg           1
# 2  000d1e9a533f62e55c289303b072733d.jpg           1
# 3  0011485b40695e9138e92d0b3fb55128.jpg           1
# 4  0014d7a11e90b62848904c1418fc8cf2.jpg           1

# %%
# Cactus
display(Image('kaggle/train/0004be2cfeaba1c0361d39e2b000257b.jpg'))
display(Image('kaggle/train/000c8a36845c0208e833c79c1bffedd1.jpg'))

# No cactus
display(Image('kaggle/train/ffede47a74e47a5930f81c0b6896479e.jpg'))
display(Image('kaggle/train/fff43acb3b7a23edcc4ae937be2b7522.jpg'))

# %%
filenames = ['kaggle/train/' + fname for fname in train_csv['id'].tolist()]
labels = train_csv['has_cactus'].tolist()


train_filenames, val_filenames, train_labels, val_labels = train_test_split(filenames,
                                                                            labels,
                                                                            train_size=0.9,
                                                                            random_state=420)

num_train = len(train_filenames)
num_val = len(val_filenames)

# %%
IMAGE_SIZE = 96


def _parse_fn(filename, label):
  image_string = tf.io.read_file(filename)
  image_decoded = tf.image.decode_jpeg(image_string)
  image_normalized = (tf.cast(image_decoded, tf.float32)/127.5) - 1
  image_resized = tf.image.resize(image_normalized, (IMAGE_SIZE, IMAGE_SIZE))
  return image_resized, label

# %%
BATCH_SIZE = 32

train_data = tf.data.Dataset.from_tensor_slices((tf.constant(train_filenames), 
                                                 tf.constant(train_labels))).map(_parse_fn).shuffle(buffer_size=10000).batch(BATCH_SIZE)


val_data = tf.data.Dataset.from_tensor_slices((tf.constant(val_filenames), 
                                               tf.constant(val_labels))).map(_parse_fn).batch(BATCH_SIZE)

# %% [markdown]
# # Define model

# %%
# Base model with MobileNetV2
IMG_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)

base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False, 
                                               weights='imagenet')
base_model.trainable = False

# %%
# Trainable classification head
maxpool_layer = tf.keras.layers.GlobalMaxPooling2D()
prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')

# %%
learning_rate = 0.0001

model = tf.keras.Sequential([
    base_model,
    maxpool_layer,
    prediction_layer
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_96 (Model)  (None, 3, 3, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
num_epochs = 30
steps_per_epoch = round(num_train)//BATCH_SIZE
val_steps = 20

# %%
history = model.fit(train_data.repeat(),
                    epochs=num_epochs,
                    steps_per_epoch = steps_per_epoch,
                    validation_data=val_data.repeat(), 
                    validation_steps=val_steps)
# Out:
# Epoch 1/30
# 492/492 [==============================] - 474s 963ms/step - loss: 0.4245 - accuracy: 0.8255 - val_loss: 0.4274 - val_accuracy: 0.7953
# Epoch 2/30
# 492/492 [==============================] - 320s 650ms/step - loss: 0.1904 - accuracy: 0.9235 - val_loss: 0.4045 - val_accuracy: 0.8172
# Epoch 3/30
# 492/492 [==============================] - 318s 647ms/step - loss: 0.1536 - accuracy: 0.9376 - val_loss: 0.3253 - val_accuracy: 0.8641
# Epoch 4/30
# 492/492 [==============================] - 301s 612ms/step - loss: 0.1341 - accuracy: 0.9482 - val_loss: 0.2915 - val_accuracy: 0.8625
# Epoch 5/30
# 492/492 [==============================] - 301s 612ms/step - loss: 0.1251 - accuracy: 0.9506 - val_loss: 0.2221 - val_accuracy: 0.9203
# Epoch 6/30
# 492/492 [==============================] - 301s 612ms/step - loss: 0.1154 - accuracy: 0.9555 - val_loss: 0.2182 - val_accuracy: 0.9125
# Epoch 7/30
# 492/492 [==============================] - 298s 607ms/step - loss: 0.1078 - accuracy: 0.9571 - val_loss: 0.2177 - val_accuracy: 0.9141
# Epoch 8/30
# 492/492 [==============================] - 300s 609ms/step - loss: 0.1038 - accuracy: 0.9603 - val_loss: 0.1701 - val_accuracy: 0.9375
# Epoch 9/30
# 492/492 [==============================] - 307s 624ms/step - loss: 0.1042 - accuracy: 0.9597 - val_loss: 0.1329 - val_accuracy: 0.9438
# Epoch 10/30
# 492/492 [==============================] - 307s 624ms/step - loss: 0.1036 - accuracy: 0.9599 - val_loss: 0.1527 - val_accuracy: 0.9406
# Epoch 11/30
# 492/492 [==============================] - 295s 600ms/step - loss: 0.0947 - accuracy: 0.9640 - val_loss: 0.1105 - val_accuracy: 0.9547
# Epoch 12/30
# 492/492 [==============================] - 296s 601ms/step - loss: 0.0911 - accuracy: 0.9651 - val_loss: 0.1119 - val_accuracy: 0.9531
# Epoch 13/30
# 492/492 [==============================] - 296s 601ms/step - loss: 0.0909 - accuracy: 0.9645 - val_loss: 0.1024 - val_accuracy: 0.9625
# Epoch 14/30
# 492/492 [==============================] - 296s 601ms/step - loss: 0.0989 - accuracy: 0.9634 - val_loss: 0.0968 - val_accuracy: 0.9641
# Epoch 15/30
# 492/492 [==============================] - 295s 599ms/step - loss: 0.0927 - accuracy: 0.9639 - val_loss: 0.0890 - val_accuracy: 0.9672
# Epoch 16/30
# 492/492 [==============================] - 296s 602ms/step - loss: 0.0947 - accuracy: 0.9634 - val_loss: 0.0894 - val_accuracy: 0.9641
# Epoch 17/30
# 492/492 [==============================] - 295s 600ms/step - loss: 0.0841 - accuracy: 0.9684 - val_loss: 0.0834 - val_accuracy: 0.9719
# Epoch 18/30
# 492/492 [==============================] - 297s 603ms/step - loss: 0.0925 - accuracy: 0.9642 - val_loss: 0.0819 - val_accuracy: 0.9719
# Epoch 19/30
# 492/492 [==============================] - 296s 602ms/step - loss: 0.0847 - accuracy: 0.9665 - val_loss: 0.0888 - val_accuracy: 0.9656
# Epoch 20/30
# 492/492 [==============================] - 297s 603ms/step - loss: 0.0856 - accuracy: 0.9658 - val_loss: 0.0789 - val_accuracy: 0.9719
# Epoch 21/30
# 492/492 [==============================] - 297s 604ms/step - loss: 0.0870 - accuracy: 0.9661 - val_loss: 0.0845 - val_accuracy: 0.9656
# Epoch 22/30
# 492/492 [==============================] - 298s 606ms/step - loss: 0.0837 - accuracy: 0.9681 - val_loss: 0.0765 - val_accuracy: 0.9672
# Epoch 23/30
# 492/492 [==============================] - 298s 606ms/step - loss: 0.0835 - accuracy: 0.9693 - val_loss: 0.0774 - val_accuracy: 0.9703
# Epoch 24/30
# 492/492 [==============================] - 299s 607ms/step - loss: 0.0827 - accuracy: 0.9685 - val_loss: 0.0802 - val_accuracy: 0.9672
# Epoch 25/30
# 492/492 [==============================] - 298s 606ms/step - loss: 0.0782 - accuracy: 0.9688 - val_loss: 0.0741 - val_accuracy: 0.9703
# Epoch 26/30
# 492/492 [==============================] - 298s 606ms/step - loss: 0.0785 - accuracy: 0.9687 - val_loss: 0.0792 - val_accuracy: 0.9688
# Epoch 27/30
# 492/492 [==============================] - 299s 608ms/step - loss: 0.0744 - accuracy: 0.9714 - val_loss: 0.0789 - val_accuracy: 0.9672
# Epoch 28/30
# 492/492 [==============================] - 299s 608ms/step - loss: 0.0831 - accuracy: 0.9670 - val_loss: 0.0748 - val_accuracy: 0.9719
# Epoch 29/30
# 492/492 [==============================] - 300s 609ms/step - loss: 0.0735 - accuracy: 0.9713 - val_loss: 0.0695 - val_accuracy: 0.9719
# Epoch 30/30
# 492/492 [==============================] - 300s 609ms/step - loss: 0.0774 - accuracy: 0.9695 - val_loss: 0.0713 - val_accuracy: 0.9719

# %%
# Save model weights
model.save_weights('weights_epoch_30.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Fine tune

# %%
# Unfreeze all layers of MobileNetV2
base_model.trainable = True

# Refreeze layers until the layers we want to fine-tune
for layer in base_model.layers[:100]:
  layer.trainable =  False

# %%
model.compile(loss='binary_crossentropy',
              optimizer = tf.keras.optimizers.Adam(lr=learning_rate/10),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_96 (Model)  (None, 3, 3, 1280)        2257984
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,863,873
# Non-trainable params: 395,392
# _________________________________________________________________

# %%
fine_tune_epochs = 30
total_epochs =  num_epochs + fine_tune_epochs

history_fine = model.fit(train_data.repeat(), 
                         steps_per_epoch = steps_per_epoch,
                         epochs=total_epochs, 
                         initial_epoch = num_epochs,
                         validation_data=val_data.repeat(), 
                         validation_steps=val_steps)
# Out:
# Epoch 31/60
# 492/492 [==============================] - 406s 826ms/step - loss: 0.0687 - accuracy: 0.9730 - val_loss: 0.0475 - val_accuracy: 0.9812
# Epoch 32/60
# 492/492 [==============================] - 383s 778ms/step - loss: 0.0488 - accuracy: 0.9824 - val_loss: 0.0341 - val_accuracy: 0.9891
# Epoch 33/60
# 492/492 [==============================] - 388s 788ms/step - loss: 0.0364 - accuracy: 0.9861 - val_loss: 0.0305 - val_accuracy: 0.9906
# Epoch 34/60
# 492/492 [==============================] - 390s 792ms/step - loss: 0.0299 - accuracy: 0.9888 - val_loss: 0.0264 - val_accuracy: 0.9906
# Epoch 35/60
# 492/492 [==============================] - 392s 796ms/step - loss: 0.0230 - accuracy: 0.9920 - val_loss: 0.0234 - val_accuracy: 0.9906
# Epoch 36/60
# 492/492 [==============================] - 391s 794ms/step - loss: 0.0207 - accuracy: 0.9929 - val_loss: 0.0204 - val_accuracy: 0.9906
# Epoch 37/60
# 492/492 [==============================] - 390s 794ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0186 - val_accuracy: 0.9922
# Epoch 38/60
# 492/492 [==============================] - 391s 794ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0150 - val_accuracy: 0.9937
# Epoch 39/60
# 492/492 [==============================] - 428s 869ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0159 - val_accuracy: 0.9922
# Epoch 40/60
# 492/492 [==============================] - 426s 866ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0145 - val_accuracy: 0.9937
# Epoch 41/60
# 492/492 [==============================] - 426s 867ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0137 - val_accuracy: 0.9953
# Epoch 42/60
# 492/492 [==============================] - 428s 870ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0127 - val_accuracy: 0.9953
# Epoch 43/60
# 492/492 [==============================] - 422s 858ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0120 - val_accuracy: 0.9937
# Epoch 44/60
# 492/492 [==============================] - 424s 862ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0099 - val_accuracy: 0.9969
# Epoch 45/60
# 492/492 [==============================] - 427s 868ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0085 - val_accuracy: 0.9969
# Epoch 46/60
# 492/492 [==============================] - 427s 867ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0102 - val_accuracy: 0.9953
# Epoch 47/60
# 492/492 [==============================] - 445s 904ms/step - loss: 0.0062 - accuracy: 0.9993 - val_loss: 0.0111 - val_accuracy: 0.9969
# Epoch 48/60
# 492/492 [==============================] - 429s 872ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0082 - val_accuracy: 0.9969
# Epoch 49/60
# 492/492 [==============================] - 428s 870ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0106 - val_accuracy: 0.9969
# Epoch 50/60
# 492/492 [==============================] - 431s 875ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0103 - val_accuracy: 0.9953
# Epoch 51/60
# 492/492 [==============================] - 432s 877ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0081 - val_accuracy: 0.9969
# Epoch 52/60
# 492/492 [==============================] - 431s 877ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0073 - val_accuracy: 0.9969
# Epoch 53/60
# 492/492 [==============================] - 418s 850ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0075 - val_accuracy: 0.9969
# Epoch 54/60
# 492/492 [==============================] - 418s 849ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0093 - val_accuracy: 0.9953
# Epoch 55/60
# 492/492 [==============================] - 417s 849ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.0100 - val_accuracy: 0.9969
# Epoch 56/60
# 492/492 [==============================] - 418s 850ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0086 - val_accuracy: 0.9969
# Epoch 57/60
# 492/492 [==============================] - 420s 853ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0074 - val_accuracy: 0.9984
# Epoch 58/60
# 492/492 [==============================] - 407s 828ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0106 - val_accuracy: 0.9953
# Epoch 59/60
# 492/492 [==============================] - 420s 853ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0125 - val_accuracy: 0.9937
# Epoch 60/60
# 492/492 [==============================] - 419s 851ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0108 - val_accuracy: 0.9922

# %%
# Save fine-tuned model weights
model.save_weights('weights_epoch_50_finetuned.h5')

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([num_epochs-1,num_epochs-1], 
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot([num_epochs-1,num_epochs-1], 
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
